# %%
import G6_iris_recognition
import os
from matplotlib import pyplot as plt
import cv2

# %%
directory = os.getcwd()
print(directory)
# Out:
# /home/chends/Documents/GitHub

# %%
G6_iris_recognition.iris_model_train("images","model.pickle")
# Out:
# directory_list ['GitHub/images/0034', 'GitHub/images/0001', 'GitHub/images/0002', 'GitHub/images/0035', 'GitHub/images/0005', 'GitHub/images/0000', 'GitHub/images/0003', 'GitHub/images/0004', 'GitHub/images/0052', 'GitHub/images/0039', 'GitHub/images/0047', 'GitHub/images/0024', 'GitHub/images/0053', 'GitHub/images/0016', 'GitHub/images/0013', 'GitHub/images/0059', 'GitHub/images/0009', 'GitHub/images/0049', 'GitHub/images/0019', 'GitHub/images/0038', 'GitHub/images/0044', 'GitHub/images/0027', 'GitHub/images/0014', 'GitHub/images/0031', 'GitHub/images/0050', 'GitHub/images/0058', 'GitHub/images/0025', 'GitHub/images/0022', 'GitHub/images/0017', 'GitHub/images/0018', 'GitHub/images/0045', 'GitHub/images/0023', 'GitHub/images/0042', 'GitHub/images/0021', 'GitHub/images/0026', 'GitHub/images/0010', 'GitHub/images/0037', 'GitHub/images/0006', 'GitHub/images/0020', 'GitHub/images/0043', 'GitHub/images/0036', 'GitHub/images/0015', 'GitHub/images/0048', 'GitHub/images/0057', 'GitHub/images
# ...

# %%
iris_name = G6_iris_recognition.iris_model_test("GitHub/model.pickle","GitHub/images/0056/0056_010.bmp")
print(iris_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15027/4044210247.py in <module>
# ----> 1 iris_name = G6_iris_recognition.iris_model_test("GitHub/model.pickle","GitHub/images/0056/0056_010.bmp")
#       2 print(iris_name)
#
# NameError: name 'G6_iris_recognition' is not defined

# %%
'''
Transformada de Wavelet, testar bases diferentes (remover detalhes)
Filtro de Canny
'''

# %%
# %matplotlib inline

image = cv2.imread('images/0000/0000_001.bmp')
# image = cv2.imread('test.jpg')
# print(image)
plt.imshow(image)
plt.show()

# image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

se = cv2.getStructuringElement(cv2.MORPH_RECT , (8,8))
bg = cv2.morphologyEx(image, cv2.MORPH_DILATE, se)
out_gray = cv2.divide(image, bg, scale=255)

plt.imshow(out_gray)
plt.show()

final = cv2.subtract(out_gray, image)
plt.imshow(final)
plt.show()

# out_binary=cv2.threshold(image, 0, 255, cv2.THRESH_OTSU )[1] 
# plt.imshow(out_binary)
# plt.show()
